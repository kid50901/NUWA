# %%
import cv2
# 載入分類器
face_cascade = cv2.CascadeClassifier(r'C:\Users\chicony\anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')
# 讀取圖片
img = cv2.imread('a.jpg')
# 轉成灰階圖片
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# 偵測臉部
faces = face_cascade.detectMultiScale(gray,scaleFactor=1.08,minNeighbors=10,minSize=(32, 32))
# 繪製人臉部份的方框
print(faces)

for (x, y, w, h) in faces:
    img = img[y-20:y+h+20, x-20:x+w+20]
    #cv2.rectangle(img, (x-20, y-20), (x + w+20, y + h+20), (0, 255, 0), 2)
#(0, 255, 0)欄位可以變更方框顏色(Blue,Green,Red)
# 顯示成果
cv2.namedWindow('img', cv2.WINDOW_NORMAL)  #正常視窗大小
cv2.imshow('img', img)                     #秀出圖片
cv2.imwrite( "result.jpg", img )           #保存圖片
cv2.waitKey(0)                             #等待按下任一按鍵
cv2.destroyAllWindows()                    #關閉視窗
# Out:
# [[176  22 111 111]]

# %%
import cv2
import os
def face_cut(img):
    face_cascade = cv2.CascadeClassifier(r'C:\Users\chicony\anaconda3\Lib\site-packages\cv2\data\haarcascade_frontalface_default.xml')
    # 轉成灰階圖片
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # 偵測臉部
    faces = face_cascade.detectMultiScale(gray,scaleFactor=1.08,minNeighbors=10,minSize=(32, 32))
    #裁減
    
    (x, y, w, h)=faces[0]
    print (x, y, w, h)
    d1=20
    d2=20
    if y<d1:
        d1=y
    if x<d2:
        d2=x
    print(d1,d2)
    img = img[y-d1:y+h+d1, x-d2:x+w+d2]
    return img

# %%
def mult_face_cut(input_path,local_path):
    imgnamelist=os.listdir(input_path)
    for i in imgnamelist:
        try:
            img = cv2.imread("{}\{}".format(input_path,i))
            print("{}\{}".format(input_path,i))
            img=face_cut(img)
            print("{}\cut_{}".format(local_path,i))
            cv2.imwrite( "{}\cut_{}".format(local_path,i), img )
        except:
            print('img_no_people')
input_path=r'C:\NUWA_img\test'
local_path=r'C:\NUWA_img\test_out'
mult_face_cut(input_path,local_path)
# Out:
# C:\NUWA_img\test\1%E9%A6%AC%E6%96%AF%E5%85%8B_a826a4585ccc0660.jpg
# 119 25 75 75
# 20 20
# C:\NUWA_img\test_out\cut_1%E9%A6%AC%E6%96%AF%E5%85%8B_a826a4585ccc0660.jpg
# C:\NUWA_img\test\10%E9%A6%AC%E6%96%AF%E5%85%8B_f07422685b3fca3e.jpg
# 100 43 46 46
# 20 20
# C:\NUWA_img\test_out\cut_10%E9%A6%AC%E6%96%AF%E5%85%8B_f07422685b3fca3e.jpg
# C:\NUWA_img\test\10musk_d9268c49fc7b60d0.jpg
# 72 31 138 138
# 20 20
# C:\NUWA_img\test_out\cut_10musk_d9268c49fc7b60d0.jpg
# C:\NUWA_img\test\11%E9%A6%AC%E6%96%AF%E5%85%8B_7c23821c8dd9922e.jpg
# 85 32 102 102
# 20 20
# C:\NUWA_img\test_out\cut_11%E9%A6%AC%E6%96%AF%E5%85%8B_7c23821c8dd9922e.jpg
# C:\NUWA_img\test\11musk_691f0f45e2daef5d.jpg
# 271 11 213 213
# 11 20
# C:\NUWA_img\test_out\cut_11musk_691f0f45e2daef5d.jpg
# C:\NUWA_img\test\12%E9%A6%AC%E6%96%AF%E5%85%8B_f08a8467bac9d27f.jpg
# 176 22 111 111
# 20 20
# C:\NUWA_img\test_out\cut_12%E9%A6%AC%E6%96%AF%E5%85%8B_f08a8467bac9d27f.jpg
# C:\NUWA_img\test\12musk_28218e12244bf98c.jpg
# 202 2 73 73
# 2 20
# C:\NUWA_img\test_out\cut_12musk_28218e12244bf98c.jpg
# C:\NUWA_img\test\13%E9%A6%AC%E6%96%AF%E5%85%8B_yH5BAEAAAAALAAAAAABAAEAAAIBRAA7.jpg
# img_no_people
# C:\NUWA_img\test\13musk_96bdb9b2c92d2ebb.jpg
# 128 19 36 36
# 19 20
# C:\NUWA_img\test_out\cut_13musk_96bdb9b2c92d2ebb.jpg
# C:\NUWA_img\test\14%E9%A6%AC%E6%96%AF%E5%85%8B_43f03072e003f1f2.jpg
# 137 40 83 83
# 20 20
# C:\NUWA_img\test_out\cut_14%E9%A6%AC%E6%96%AF%E5%85%8B_43f03072e003f1f2.jpg
# C:\NUWA_img\test\14musk_yH5BAEAAAAALAAAAAABAAEAAAIBRAA7.jpg
# img_no_people
# C:\NUWA_img\test\15%E9%A6%AC%E6%96%AF%E5%85%8B_fb61041a23a48821.jpg
# 91 24 141 141
# 20 20
# C:\NUWA_img\test_out\cut_15%E9%A6%AC%E6%96%AF%E5%85%8B_fb61041a23a48821.jpg
# C:\NUWA_img\test\15musk_9228122f81151057.jpg
# 301 66 151 151
# 20 20
# C:\NUWA_img\test_out\cut_15musk_9228122f81151057.jpg
# C:\NUWA_img\test\16%E9%A6%AC%E6%96%AF%E5%85%8B_79109b4f5d1bb1ee.jpg
# 131 42 73 73
# 20 20
# C:\NUWA_img\test_out\cut_16%E9%A6%AC%E6%96%AF%E5%85%8B_79109b4f5d1bb1ee.jpg
# C:\NUWA_img\test\16musk_75b2ff25b709cac5.jpg
# 175 27 86 86
# 20 20
# C:\NUWA_img\test_out\cut_16musk_75b2ff25b709cac5.jpg
# C:\NUWA_img\test\17%E9%A6%AC%E6%96%AF%E5%85%8B_39b59f00ca11955e.jpg
# 167 29 91 91
# 20 20
# C:\NUWA_img\test_out\cut_17%E9%A6%AC%E6%96%AF%E5%85%8B_39b59f00ca11955e.jpg
# C:\NUWA_img\test\17musk_e89edcfbe1a47ad3.jpg
# 85 33 115 115
# 20 20
# C:\NUWA_img\test_out\cut_17musk_e89edcfbe1a47ad3.jpg
# C:\NUWA_img\test\18%E9%A6%AC%E6%96%AF%E5%85%8B_3ea2d2cfaa9a71af.jpg
# 88 27 103 103
# 20 20
# C:\NUWA_img\test_out\cut_18%E9%A6%AC%E6%96%AF%E5%85%8B_3ea2d2cfaa9a71af.jpg
# C:\NUWA_img\test\18musk_a1aafe58ebd2abc5.jpg
# img_no_people
# C:\NUWA_img\test\19%E9%A6%AC%E6%96%AF%E5%85%8B_1d03c220903c4ddf.jpg
# 115 27 63 63
# 20 20
# C:\NUWA_img\test_out\cut_19%E9%A6%AC%E6%96%AF%E5%85%8B_1d03c220903c4ddf.jpg
# C:\NUWA_img\test\19musk_9ea7b6d6e90792b9.jpg
# 203 147 56 56
# 20 20
# C:\NUWA_img\test_out\cut_19musk_9ea7b6d6e90792b9.jpg
# C:\NUWA_img\test\1musk_d41ea4fc8a6be519.jpg
# 250 281 117 117
# 20 20
# C:\NUWA_img\test_out\cut_1musk_d41ea4fc8a6be519.jpg
# C:\NUWA_img\test\2%E9%A6%AC%E6%96%AF%E5%85%8B_b709fcd2b95e1fd8.jpg
# 95 55 102 102
# 20 20
# C:\NUWA_img\test_out\cut_2%E9%A6%AC%E6%96%AF%E5%85%8B_b709fcd2b95e1fd8.jpg
# C:\NUWA_img\test\20%E9%A6%AC%E6%96%AF%E5%85%8B_182d01e36fa12605.jpg
# 119 13 52 52
# 13 20
# C:\NUWA_img\test_out\cut_20%E9%A6%AC%E6%96%AF%E5%85%8B_182d01e36fa12605.jpg
# C:\NUWA_img\test\20musk_66904c1d19fe07ae.jpg
# 84 42 103 103
# 20 20
# C:\NUWA_img\test_out\cut_20musk_66904c1d19fe07ae.jpg
# C:\NUWA_img\test\21%E9%A6%AC%E6%96%AF%E5%85%8B_632bc107090e2ecf.jpg
# 217 71 167 167
# 20 20
# C:\NUWA_img\test_out\cut_21%E9%A6%AC%E6%96%AF%E5%85%8B_632bc107090e2ecf.jpg
# C:\NUWA_img\test\21musk_a64bbe3e0a9ecd9c.jpg
# 131 37 80 80
# 20 20
# C:\NUWA_img\test_out\cut_21musk_a64bbe3e0a9ecd9c.jpg
# C:\NUWA_img\test\22%E9%A6%AC%E6%96%AF%E5%85%8B_243d20da1fe23ebe.jpg
# 134 25 57 57
# 20 20
# C:\NUWA_img\test_out\cut_22%E9%A6%AC%E6%96%AF%E5%85%8B_243d20da1fe23ebe.jpg
# C:\NUWA_img\test\22musk_fb59c0acd877a0d6.jpg
# 299 79 92 92
# 20 20
# C:\NUWA_img\test_out\cut_22musk_fb59c0acd877a0d6.jpg
# C:\NUWA_img\test\23%E9%A6%AC%E6%96%AF%E5%85%8B_5ac7e8d02e914e31.jpg
# 131 39 62 62
# 20 20
# C:\NUWA_img\test_out\cut_23%E9%A6%AC%E6%96%AF%E5%85%8B_5ac7e8d02e914e31.jpg
# C:\NUWA_img\test\23musk_5ccc441228e828bf.jpg
# 147 64 102 102
# 20 20
# C:\NUWA_img\test_out\cut_23musk_5ccc441228e828bf.jpg
# C:\NUWA_img\test\24%E9%A6%AC%E6%96%AF%E5%85%8B_dc9604c45381f7f9.jpg
# 86 33 134 134
# 20 20
# C:\NUWA_img\test_out\cut_24%E9%A6%AC%E6%96%AF%E5%85%8B_dc9604c45381f7f9.jpg
# C:\NUWA_img\test\24musk_95de6e09428bfe7c.jpg
# 122 26 65 65
# 20 20
# C:\NUWA_img\test_out\cut_24musk_95de6e09428bfe7c.jpg
# C:\NUWA_img\test\25%E9%A6%AC%E6%96%AF%E5%85%8B_d7f4d3e89e344eb8.jpg
# 91 44 108 108
# 20 20
# C:\NUWA_img\test_out\cut_25%E9%A6%AC%E6%96%AF%E5%85%8B_d7f4d3e89e344eb8.jpg
# C:\NUWA_img\test\25musk_e066481d54911056.jpg
# 77 39 91 91
# 20 20
# C:\NUWA_img\test_out\cut_25musk_e066481d54911056.jpg
# C:\NUWA_img\test\26%E9%A6%AC%E6%96%AF%E5%85%8B_b8d18818b310c08e.jpg
# 117 14 103 103
# 14 20
# C:\NUWA_img\test_out\cut_26%E9%A6%AC%E6%96%AF%E5%85%8B_b8d18818b310c08e.jpg
# C:\NUWA_img\test\26musk_f7ac2a602b8f2f1e.jpg
# 207 14 75 75
# 14 20
# C:\NUWA_img\test_out\cut_26musk_f7ac2a602b8f2f1e.jpg
# C:\NUWA_img\test\27%E9%A6%AC%E6%96%AF%E5%85%8B_af54e326d10318e6.jpg
# img_no_people
# C:\NUWA_img\test\27musk_a889036de757226d.jpg
# 88 38 135 135
# 20 20
# C:\NUWA_img\test_out\cut_27musk_a889036de757226d.jpg
# C:\NUWA_img\test\28%E9%A6%AC%E6%96%AF%E5%85%8B_fa83285bcb91ee8c.jpg
# 40 24 156 156
# 20 20
# C:\NUWA_img\test_out\cut_28%E9%A6%AC%E6%96%AF%E5%85%8B_fa83285bcb91ee8c.jpg
# C:\NUWA_img\test\28musk_4e9e1982e5692431.jpg
# 61 66 86 86
# 20 20
# C:\NUWA_img\test_out\cut_28musk_4e9e1982e5692431.jpg
# C:\NUWA_img\test\29%E9%A6%AC%E6%96%AF%E5%85%8B_b8ed67e7bb75e766.jpg
# 130 47 49 49
# 20 20
# C:\NUWA_img\test_out\cut_29%E9%A6%AC%E6%96%AF%E5%85%8B_b8ed67e7bb75e766.jpg
# C:\NUWA_img\test\29musk_af75f1be4a6bc8f8.jpg
# 171 63 98 98
# 20 20
# C:\NUWA_img\test_out\cut_29musk_af75f1be4a6bc8f8.jpg
# C:\NUWA_img\test\2musk_f0c1af460b00fa30.jpg
# 14 52 144 144
# 20 14
# C:\NUWA_img\test_out\cut_2musk_f0c1af460b00fa30.jpg
# C:\NUWA_img\test\3%E9%A6%AC%E6%96%AF%E5%85%8B_23e92758e12e1d2a.jpg
# 107 17 80 80
# 17 20
# C:\NUWA_img\test_out\cut_3%E9%A6%AC%E6%96%AF%E5%85%8B_23e92758e12e1d2a.jpg
# C:\NUWA_img\test\30%E9%A6%AC%E6%96%AF%E5%85%8B_e10d7d5b1e4d1b64.jpg
# 60 28 147 147
# 20 20
# C:\NUWA_img\test_out\cut_30%E9%A6%AC%E6%96%AF%E5%85%8B_e10d7d5b1e4d1b64.jpg
# C:\NUWA_img\test\30musk_1a8da60874a44158.jpg
# 129 39 114 114
# 20 20
# C:\NUWA_img\test_out\cut_30musk_1a8da60874a44158.jpg
# C:\NUWA_img\test\31%E9%A6%AC%E6%96%AF%E5%85%8B_835f7ff26581f04b.jpg
# 142 42 107 107
# 20 20
# C:\NUWA_img\test_out\cut_31%E9%A6%AC%E6%96%AF%E5%85%8B_835f7ff26581f04b.jpg
# C:\NUWA_img\test\31musk_8a3972f32aead436.jpg
# 80 71 62 62
# 20 20
# C:\NUWA_img\test_out\cut_31musk_8a3972f32aead436.jpg
# C:\NUWA_img\test\32%E9%A6%AC%E6%96%AF%E5%85%8B_6a3326536f457bd1.jpg
# 128 6 158 158
# 6 20
# C:\NUWA_img\test_out\cut_32%E9%A6%AC%E6%96%AF%E5%85%8B_6a3326536f457bd1.jpg
# C:\NUWA_img\test\32musk_3619026f25f330d4.jpg
# 34 65 152 152
# 20 20
# C:\NUWA_img\test_out\cut_32musk_3619026f25f330d4.jpg
# C:\NUWA_img\test\33%E9%A6%AC%E6%96%AF%E5%85%8B_aaa5d2633111b50e.jpg
# 103 37 128 128
# 20 20
# C:\NUWA_img\test_out\cut_33%E9%A6%AC%E6%96%AF%E5%85%8B_aaa5d2633111b50e.jpg
# C:\NUWA_img\test\33musk_53d0b52928003589.jpg
# img_no_people
# C:\NUWA_img\test\34%E9%A6%AC%E6%96%AF%E5%85%8B_9be68321465ab1ce.jpg
# 89 99 59 59
# 20 20
# C:\NUWA_img\test_out\cut_34%E9%A6%AC%E6%96%AF%E5%85%8B_9be68321465ab1ce.jpg
# C:\NUWA_img\test\34musk_c482480a460acbb8.jpg
# 28 67 155 155
# 20 20
# C:\NUWA_img\test_out\cut_34musk_c482480a460acbb8.jpg
# C:\NUWA_img\test\35%E9%A6%AC%E6%96%AF%E5%85%8B_8956b09923a8d8ce.jpg
# 112 26 57 57
# 20 20
# C:\NUWA_img\test_out\cut_35%E9%A6%AC%E6%96%AF%E5%85%8B_8956b09923a8d8ce.jpg
# C:\NUWA_img\test\35musk_5c1ba88ba69ed80f.jpg
# 78 14 141 141
# 14 20
# C:\NUWA_img\test_out\cut_35musk_5c1ba88ba69ed80f.jpg
# C:\NUWA_img\test\36%E9%A6%AC%E6%96%AF%E5%85%8B_8730bfbbcf3099ba.jpg
# 71 41 126 126
# 20 20
# C:\NUWA_img\test_out\cut_36%E9%A6%AC%E6%96%AF%E5%85%8B_8730bfbbcf3099ba.jpg
# C:\NUWA_img\test\36musk_10d4fa6ceb67263f.jpg
# 164 33 154 154
# 20 20
# C:\NUWA_img\test_out\cut_36musk_10d4fa6ceb67263f.jpg
# C:\NUWA_img\test\37%E9%A6%AC%E6%96%AF%E5%85%8B_ba1e7bd911c7c7af.jpg
# img_no_people
# C:\NUWA_img\test\37musk_61a9fe95e6f7ef3f.jpg
# 298 38 77 77
# 20 20
# C:\NUWA_img\test_out\cut_37musk_61a9fe95e6f7ef3f.jpg
# C:\NUWA_img\test\38%E9%A6%AC%E6%96%AF%E5%85%8B_69fcc9eb3f220a62.jpg
# img_no_people
# C:\NUWA_img\test\38musk_548c996bb4dbf070.jpg
# 151 16 72 72
# 16 20
# C:\NUWA_img\test_out\cut_38musk_548c996bb4dbf070.jpg
# C:\NUWA_img\test\39%E9%A6%AC%E6%96%AF%E5%85%8B_a0fca0805bf4f111.jpg
# 125 45 39 39
# 20 20
# C:\NUWA_img\test_out\cut_39%E9%A6%AC%E6%96%AF%E5%85%8B_a0fca0805bf4f111.jpg
# C:\NUWA_img\test\39musk_0b03d7b475dcdd0a.jpg
# 173 40 155 155
# 20 20
# C:\NUWA_img\test_out\cut_39musk_0b03d7b475dcdd0a.jpg
# C:\NUWA_img\test\3musk_f004023af8627531.jpg
# 93 32 100 100
# 20 20
# C:\NUWA_img\test_out\cut_3musk_f004023af8627531.jpg
# C:\NUWA_img\test\4%E9%A6%AC%E6%96%AF%E5%85%8B_94983bd0053b40bd.jpg
# 119 62 65 65
# 20 20
# C:\NUWA_img\test_out\cut_4%E9%A6%AC%E6%96%AF%E5%85%8B_94983bd0053b40bd.jpg
# C:\NUWA_img\test\40%E9%A6%AC%E6%96%AF%E5%85%8B_6fe17360b9160133.jpg
# 97 27 124 124
# 20 20
# C:\NUWA_img\test_out\cut_40%E9%A6%AC%E6%96%AF%E5%85%8B_6fe17360b9160133.jpg
# C:\NUWA_img\test\40musk_70ea7511aa0492d5.jpg
# 186 40 171 171
# 20 20
# C:\NUWA_img\test_out\cut_40musk_70ea7511aa0492d5.jpg
# C:\NUWA_img\test\41%E9%A6%AC%E6%96%AF%E5%85%8B_f832e5c67aa5e6b6.jpg
# 116 4 68 68
# 4 20
# C:\NUWA_img\test_out\cut_41%E9%A6%AC%E6%96%AF%E5%85%8B_f832e5c67aa5e6b6.jpg
# C:\NUWA_img\test\41musk_1b01d49b6726cddf.jpg
# 143 59 138 138
# 20 20
# C:\NUWA_img\test_out\cut_41musk_1b01d49b6726cddf.jpg
# C:\NUWA_img\test\42musk_90999083bab10d47.jpg
# 118 35 98 98
# 20 20
# C:\NUWA_img\test_out\cut_42musk_90999083bab10d47.jpg
# C:\NUWA_img\test\43musk_9b0ad5b30815777f.jpg
# 228 70 172 172
# 20 20
# C:\NUWA_img\test_out\cut_43musk_9b0ad5b30815777f.jpg
# C:\NUWA_img\test\4musk_94d6dc8d9ef2655b.jpg
# 43 47 154 154
# 20 20
# C:\NUWA_img\test_out\cut_4musk_94d6dc8d9ef2655b.jpg
# C:\NUWA_img\test\5%E9%A6%AC%E6%96%AF%E5%85%8B_73d73ebce0d8c9f3.jpg
# 185 62 170 170
# 20 20
# C:\NUWA_img\test_out\cut_5%E9%A6%AC%E6%96%AF%E5%85%8B_73d73ebce0d8c9f3.jpg
# C:\NUWA_img\test\5musk_5a5a5c17b33c3ed8.jpg
# 131 139 229 229
# 20 20
# C:\NUWA_img\test_out\cut_5musk_5a5a5c17b33c3ed8.jpg
# C:\NUWA_img\test\6%E9%A6%AC%E6%96%AF%E5%85%8B_975e8bb2964aa2c6.jpg
# 66 18 58 58
# 18 20
# C:\NUWA_img\test_out\cut_6%E9%A6%AC%E6%96%AF%E5%85%8B_975e8bb2964aa2c6.jpg
# C:\NUWA_img\test\6musk_dc79ae678847830f.jpg
# 60 57 96 96
# 20 20
# C:\NUWA_img\test_out\cut_6musk_dc79ae678847830f.jpg
# C:\NUWA_img\test\7%E9%A6%AC%E6%96%AF%E5%85%8B_723d78cb10cfa8e2.jpg
# 205 68 97 97
# 20 20
# C:\NUWA_img\test_out\cut_7%E9%A6%AC%E6%96%AF%E5%85%8B_723d78cb10cfa8e2.jpg
# C:\NUWA_img\test\7musk_c76f772db2945144.jpg
# 58 50 126 126
# 20 20
# C:\NUWA_img\test_out\cut_7musk_c76f772db2945144.jpg
# C:\NUWA_img\test\8%E9%A6%AC%E6%96%AF%E5%85%8B_6df7bfd1cda8d7bd.jpg
# 126 23 72 72
# 20 20
# C:\NUWA_img\test_out\cut_8%E9%A6%AC%E6%96%AF%E5%85%8B_6df7bfd1cda8d7bd.jpg
# C:\NUWA_img\test\8musk_bfcc24fff03000d0.jpg
# 208 55 115 115
# 20 20
# C:\NUWA_img\test_out\cut_8musk_bfcc24fff03000d0.jpg
# C:\NUWA_img\test\9%E9%A6%AC%E6%96%AF%E5%85%8B_54dadf60aaa3a5b1.jpg
# 135 49 147 147
# 20 20
# C:\NUWA_img\test_out\cut_9%E9%A6%AC%E6%96%AF%E5%85%8B_54dadf60aaa3a5b1.jpg
# C:\NUWA_img\test\9musk_ea08b2687bdaa100.jpg
# 179 24 173 173
# 20 20
# C:\NUWA_img\test_out\cut_9musk_ea08b2687bdaa100.jpg

# %%
# Out:
# ['10musk_f07422685b3fca3e.jpg',
#  '11musk_7c23821c8dd9922e.jpg',
#  '12musk_f08a8467bac9d27f.jpg',
#  '13musk_yH5BAEAAAAALAAAAAABAAEAAAIBRAA7.jpg',
#  '14musk_43f03072e003f1f2.jpg',
#  '15musk_fb61041a23a48821.jpg',
#  '16musk_79109b4f5d1bb1ee.jpg',
#  '17musk_39b59f00ca11955e.jpg',
#  '18musk_3ea2d2cfaa9a71af.jpg',
#  '19musk_1d03c220903c4ddf.jpg',
#  '1musk_a826a4585ccc0660.jpg',
#  '20musk_182d01e36fa12605.jpg',
#  '21musk_632bc107090e2ecf.jpg',
#  '22musk_243d20da1fe23ebe.jpg',
#  '23musk_5ac7e8d02e914e31.jpg',
#  '24musk_dc9604c45381f7f9.jpg',
#  '25musk_d7f4d3e89e344eb8.jpg',
#  '26musk_b8d18818b310c08e.jpg',
#  '27musk_af54e326d10318e6.jpg',
#  '28musk_fa83285bcb91ee8c.jpg',
#  '29musk_b8ed67e7bb75e766.jpg',
#  '2musk_b709fcd2b95e1fd8.jpg',
#  '30musk_e10d7d5b1e4d1b64.jpg',
#  '31musk_835f7ff26581f04b.jpg',
#  '32musk_6a3326536f457bd1.jpg',
#  '33musk_aaa5d2633111b50e.jpg',
#  '34musk_9be68321465ab1ce.jpg',
#  '35musk_8956b09923a8d8ce.jpg',
#  '36musk_8730bfbbcf3099ba.jpg',
#  '37musk_ba1e7bd911c7c7af.jpg',
#  '38musk_69fcc9eb3f220a62.jpg',
#  '39musk_a0fca0805bf4f111.jpg',
#  '3musk_23e92758e12e1d2a.jpg',
#  '40musk_6fe17360b9160133.jpg',
#  '41musk_f832e5c67aa5e6b6.jpg',
#  '4musk_94983bd0053b40bd.jpg',
#  '5musk_73d73ebce0d8c9f3.jpg',
#  '6musk_975e8bb2964aa2c6.jpg',
#  '7musk_723d78cb10cfa8e2.jpg',
#  '8musk_6df7bfd1cda8d7bd.jpg',
#  '9musk_54dadf60aaa3a5b1.jpg']
